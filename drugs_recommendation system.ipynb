# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import math
import numpy as np
data=pd.read_csv(r'C:\Users\ankitha\medicine.csv')

# %%
data
# Out:
#        Unnamed: 0                                          Drug_Name Reason  \
# 0               0               A CN Gel(Topical) 20gmA CN Soap 75gm   Acne
# 1               1  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...   Acne
# 2               2                             ACGEL CL NANO Gel 15gm   Acne
# 3               3                                ACGEL NANO Gel 15gm   Acne
# 4               4                              Acleen 1% Lotion 25ml   Acne
# ...           ...                                                ...    ...
# 22462       22476                                T Muce Ointment 5gm  Wound
# 22463       22477  Wokadine 10% Solution 100mlWokadine Solution 5...  Wound
# 22464       22478                               Wokadine M Onit 10gm  Wound
# 22465       22479                           Wound Fix Solution 100ml  Wound
# 22466       22480                              Wounsol Ointment 15gm  Wound
#
#                                              Description
# ...

# %%
data[data.duplicated(subset=['Drug_Name'],keep=False)]
# Out:
#        Unnamed: 0                   Drug_Name      Reason  \
# 7632         7646          Gefer Capsule 10'S     General
# 7663         7677  M Cold Plus CZ Tablet 10'S     General
# 15680       15694  M Cold Plus CZ Tablet 10'S        Pain
# 19496       19510          Gefer Capsule 10'S  Supplement
#
#                                              Description
# 7632                              used for hygienic body
# 7663                                         heals cough
# 15680  used to relieve abdominal pain, spasmodic dysm...
# 19496  with cytoprotective effects, to help in the he...

# %%
data['Drug_Name'].describe()
# Out:
# count                  22467
# unique                 22465
# top       Gefer Capsule 10'S
# freq                       2
# Name: Drug_Name, dtype: object

# %%
list1=['vikas','ankitha']

# %%
data["doctors"] = np.random.choice(list1, size=len(data))

# %%
data['age'] = np.random.randint(5, 80, data.shape[0])

# %%
data['count'] = np.random.randint(0, 30, data.shape[0])

# %%
data['count_doctor'] = np.random.randint(1, 20, data.shape[0])

# %%
data
# Out:
#        Unnamed: 0                                          Drug_Name Reason  \
# 0               0               A CN Gel(Topical) 20gmA CN Soap 75gm   Acne
# 1               1  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...   Acne
# 2               2                             ACGEL CL NANO Gel 15gm   Acne
# 3               3                                ACGEL NANO Gel 15gm   Acne
# 4               4                              Acleen 1% Lotion 25ml   Acne
# ...           ...                                                ...    ...
# 22462       22476                                T Muce Ointment 5gm  Wound
# 22463       22477  Wokadine 10% Solution 100mlWokadine Solution 5...  Wound
# 22464       22478                               Wokadine M Onit 10gm  Wound
# 22465       22479                           Wound Fix Solution 100ml  Wound
# 22466       22480                              Wounsol Ointment 15gm  Wound
#
# ...

# %%
data.to_csv('drugs.csv')

# %%
list1=process.extract('fever', data['Description'].to_list(), limit = 1)

# %%
list1
# Out:
# [('short-term treatment of fever', 90)]

# %%
list2=[]
for i in list1:
    for j in i:
        if(type(j) == str):
            list2.append(j)
res = []
for i in list2:
    if i not in res:
        res.append(i)     
data1=data[data['Description'].isin(res)]

# %%
data1
# Out:
#       Unnamed: 0                                          Drug_Name Reason  \
# 6519        6533                       1000 Para 1000mg Tablet 12'S  Fever
# 6520        6534                   Aalcetamol 1000mg Infusion 100ml  Fever
# 6521        6535                             ACETO 250mg Syrup 60ml  Fever
# 6522        6536                       Agpar 125mg Suspension 450ml  Fever
# 6523        6537                           ALGINA 500MG TABLET 10'S  Fever
# 6524        6538                                 AMIDOL Tablet 10's  Fever
# 6525        6539                         Anaflam P Suspension 100ml  Fever
# 6526        6540  Anglopar 125mg Drops 15mlAnglopar 500mg Tablet...  Fever
# 6527        6541  Babygesic 250mg Syrup 60mlBabygesic 125mg Syru...  Fever
# 6528        6542                  Bestogesic Fast 650mg Tablet 10'S  Fever
# 6529        6543  Biocetamol 60mg Syrup 60mlBiocetamol 100mg Dro...  Fever
# ...

# %%
maximum_count_wholedoctor=data1['count'].max()

# %%
maximum_count_wholedoctor
# Out:
# 29

# %%
data2=data1[data1['doctors'].str.contains('vikas')]

# %%
data2
# Out:
#       Unnamed: 0                                          Drug_Name Reason  \
# 6519        6533                       1000 Para 1000mg Tablet 12'S  Fever
# 6521        6535                             ACETO 250mg Syrup 60ml  Fever
# 6526        6540  Anglopar 125mg Drops 15mlAnglopar 500mg Tablet...  Fever
# 6527        6541  Babygesic 250mg Syrup 60mlBabygesic 125mg Syru...  Fever
# 6528        6542                  Bestogesic Fast 650mg Tablet 10'S  Fever
# 6529        6543  Biocetamol 60mg Syrup 60mlBiocetamol 100mg Dro...  Fever
# 6530        6544                         Biopyrin 650mg Tablet 15'S  Fever
# 6531        6545                          Brikamol 250mg Syrup 60ml  Fever
# 6532        6546                        Brucet 400/333mg Tablet 3'S  Fever
# 6534        6548                           Calipar 250mg Syrup 60ml  Fever
# 6535        6549  Calpol 100mg Drops 15mlCalpol 650mg Tablet 10'...  Fever
#
# ...

# %%
maximun_count_doctor=data2['count_doctor'].max()

# %%
maximun_count_doctor
# Out:
# 18

# %%
whole_doctor_count=data1[data1['count'] ==maximum_count_wholedoctor]

# %%
whole_doctor_count
# Out:
#       Unnamed: 0                                          Drug_Name Reason  \
# 6529        6543  Biocetamol 60mg Syrup 60mlBiocetamol 100mg Dro...  Fever
#
#                         Description doctors  age  count  count_doctor
# 6529  short-term treatment of fever   vikas   68     29            15

# %%
doctor_count=data2[data2['count_doctor'] ==maximun_count_doctor]

# %%
doctor_count
# Out:
#       Unnamed: 0                                          Drug_Name Reason  \
# 6535        6549  Calpol 100mg Drops 15mlCalpol 650mg Tablet 10'...  Fever
#
#                         Description doctors  age  count  count_doctor
# 6535  short-term treatment of fever   vikas   65     19            18

# %%
maximun_count_doctor=data1['count_doctor'].max()

# %%
maximum_count_wholedoctor=data1['count'].max()

# %%
data2=data1[data1['count'] ==maximum_count_wholedoctor]

# %%
data3=data1[data1['count_doctor']==maximun_count_doctor]

# %%
data3
# Out:
#       Unnamed: 0                 Drug_Name Reason  \
# 6523        6537  ALGINA 500MG TABLET 10'S  Fever
# 6542        6556       Coldmine Syrup 60ml  Fever
#
#                         Description  doctors  age  count  count_doctor
# 6523  short-term treatment of fever  ankitha   77      9            19
# 6542  short-term treatment of fever  ankitha   45     28            19

# %%
data2=data2[data2['doctors'].str.contains('vikas')]

# %%
data2
# Out:
#       Unnamed: 0                                          Drug_Name Reason  \
# 6529        6543  Biocetamol 60mg Syrup 60mlBiocetamol 100mg Dro...  Fever
#
#                         Description doctors  age  count  count_doctor
# 6529  short-term treatment of fever   vikas   68     29            15

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.

# %%
data['Drug_id']= label_encoder.fit_transform(data['Drug_Name'])

# %%
data.to_csv('drugs.csv')

# %%
list1=process.extract("cough", data['Description'].to_list(), limit = 1)
list2=[]
for i in list1:
    for j in i:
        if(type(j) == str):
            list2.append(j)
res = []
for i in list2:
    if i not in res:
        res.append(i)     

data1=data[data['Description'].isin(res)]
#data1.drop_duplicates(subset='Drug_Name')
data2=data1[data1['doctors'].str.contains("ankitha")]

# %%
data2
# Out:
#       Unnamed: 0                                          Drug_Name   Reason  \
# 7555        7569                                 Abdifer Drops 15ml  General
# 7564        7578                               Alite Face Wash 50gm  General
# 7573        7587                      Avarta Anti Ageing Cream 50gm  General
# 7582        7596                        Cetaphil Baby Shampoo 200ml  General
# 7600        7614     Cutiyt Total Cream 15gmCutiyt Total Cream 30gm  General
# 7618        7632                            Ethiglo Face Wash 200gm  General
# 7663        7677                         M Cold Plus CZ Tablet 10'S  General
# 7672        7686  Mesoestetic Lactic Peel AL 50% Gel 50mlMesoest...  General
# 7681        7695                                 MY FAIR Cream 20gm  General
# 7690        7704                                  Nt Age Cream 50gm  General
# 7726        7740              Sebamed Anti Hair Loss Shampoo 200 ml  General
# ...

# %%
data2.drop(columns=['Unnamed: 0'],inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data2
# Out:
#                                         Drug_Name   Reason Description  \
# 7556                       AC Rinz Face Wash 60ml  General  heals cold
# 7583  CETAPHIL BABY GENTLE WASH AND Shampoo 230ml  General  heals cold
# 7637                             Glymed Soap 75gm  General  heals cold
# 7673         Mesoestetic Melanostop Peel Gel 50ml  General  heals cold
# 7754           Sper Optimum Sunscreen Lotion 60gm  General  heals cold
#
#       doctors  age
# 7556  ankitha   29
# 7583  ankitha   32
# 7637  ankitha   54
# 7673  ankitha   34
# 7754  ankitha   21

# %%
duplicate = data[data.duplicated('Drug_Name')]

# %%
duplicate
# Out:
#        Unnamed: 0                   Drug_Name      Reason  \
# 15680       15694  M Cold Plus CZ Tablet 10'S        Pain
# 19496       19510          Gefer Capsule 10'S  Supplement
#
#                                              Description doctors  age
# 15680  used to relieve abdominal pain, spasmodic dysm...    raju   62
# 19496  with cytoprotective effects, to help in the he...   vikas   58
